# %%
import pandas as pd
from os import walk
import matplotlib.pyplot as plt
from CritRole.Common import EDamageTypes
from CritRole.Common import validOrZero
import matplotlib.colors as mplc

globalData = {}
accmData = []

gindex = 0

def process_file(root, x, character):
    global gindex
    fileindex = x.split('.')[0].zfill(3)
#    if not x == "64.html.csv":# and not x == "44.html.csv" and not x == "33.html.csv":
#       return
    #print("Processing file: " + str(x))
    eviFrame = pd.read_csv(root + x, index_col=0);
    retable = eviFrame.index.values
    #print(eviFrame["PhysicalInstVals"][0:20])
    #eviFrame = eviFrame.loc[:, EDamageTypes[0]:EDamageTypes[len(EDamageTypes) - 1]+"Instances"]
    eviFrame = eviFrame.loc[:, EDamageTypes[0]:EDamageTypes[len(EDamageTypes) - 1]]
    eviFrame = eviFrame.iloc[[(character)]]
    #eviFrame = eviFrame.rename(index={1: gindex})
    eviFrame.index.name = "Episode"
    last = eviFrame.index[-1]
    eviFrame = eviFrame.rename(index={last: str(fileindex)})
    #eviFrame["Episode"] = fileindex
    gindex += 1
    # + eviFrame[2:8]
    #eviFrame = eviFrame.drop(['Trinket'])
    #print(eviFrame)
    
    #print(character)
    if len(accmData) > character:
        #accmData[0].append(eviFrame, ignore_index=True);
        accmData[character] = pd.concat([accmData[character], eviFrame]);
        #print(gindex)
        #print(accmData[0])
    else:
        accmData.append(eviFrame);
        #print(accmData[0])
        

    #print(eviFrame)
    #print(accmData)
#    print(eviFrame.shape[0])
    for i in range(0, len(EDamageTypes)):
        #print(eviFrame.columns[i]);
        dAgg = eviFrame[eviFrame.columns[i]];

        if EDamageTypes[i] in globalData:
            globalData[EDamageTypes[i]][0] += dAgg
        else:
            globalData[EDamageTypes[i]] = []
            globalData[EDamageTypes[i]].append(dAgg)
#        DamageAgg = eviFrame[''
    return retable, fileindex
        
# Enumerate the folder
damageTakens = []
rootDirectory = "./ParsedDamageTaken/"
for (dirpath, dirnames, filenames) in walk(rootDirectory):
    damageTakens.extend(filenames)

chararr = []

# Lightning  Poison  Fire  Falling  Radiant  Necrotic  Psychic  Ice  Acid  Thunder  Physical  
colorsList = [
    (1,1,0),
    (0.05,0.5,0.05),
    (1,0.25,0),
    (0.5,0.5,0.7),
    (1,0.8,0.05), # Radiant
    (0.5,0.25,0),
    (0.8,0.0,0.8), #Phychic
    (0.5,0.7,1.0),
    (0,1,0), #Acid
    (1,1,1),
    (0.9,0.9,1.0)
]
CustomCmap = mplc.ListedColormap(colorsList)


        
    #accmData[chars] = accmData[chars].sort_index()
    #print("======= CHAR " + str(chars) + " ========")

# %%
gi = 0
import gc
for singleFile in damageTakens:
    gi += 1
    accmData = []
    for chars in range(0,7):
        chararr, ii = process_file(rootDirectory, singleFile, chars)
        ll = plt.figure(dpi=99)#;, facecolor='w', edgecolor='k')
        #plt.figure(figsize=(20,10))
        #gplt = accmData[0].plot.area(stacked=True, figsize=(48,27), colormap="tab20c")
        print(accmData[chars].squeeze())
        gplt = accmData[chars].squeeze().plot.pie(ax = plt.gca(), stacked=False, figsize=(32,18), colormap=CustomCmap)
        gplt.set_facecolor('#121212')
        #gplt.plot()
        plt.savefig("perepi/" + chararr[chars] + ".pie.taken." + str(ii) +".png")
        ll.clf()
        plt.close()
        gc.collect()
# Out:
# Lightning      0
# Poison       105
# Fire           0
# Falling        0
# Radiant        0
# Necrotic       0
# Psychic        0
# Ice            0
# Acid           0
# Thunder        0
# Physical      29
# Name: 066, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 066, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     30
# Name: 066, dtype: int64
# Lightning     0
# Poison       25
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 066, dtype: int64
# Lightning     4
# Poison       55
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 066, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 066, dtype: int64
# Lightning     0
# Poison       26
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 066, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      5
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 040, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice          63
# Acid          0
# Thunder       0
# Physical     14
# Name: 040, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 040, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice          32
# Acid          0
# Thunder       0
# Physical     17
# Name: 040, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 040, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 040, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 040, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 021, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 021, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid         25
# Thunder       0
# Physical     55
# Name: 021, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 021, dtype: int64
# Lightning      0
# Poison         0
# Fire           0
# Falling        0
# Radiant        0
# Necrotic       0
# Psychic        0
# Ice            0
# Acid           0
# Thunder        0
# Physical     105
# Name: 021, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 021, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 021, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 069, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 069, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 069, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 069, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 069, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 069, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 069, dtype: int64
# Lightning    79
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     18
# Name: 088, dtype: int64
# Lightning    66
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     10
# Name: 088, dtype: int64
# Lightning    35
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     98
# Name: 088, dtype: int64
# Lightning     71
# Poison         0
# Fire          22
# Falling        0
# Radiant        0
# Necrotic       0
# Psychic        0
# Ice            0
# Acid          45
# Thunder        0
# Physical     124
# Name: 088, dtype: int64
# Lightning    84
# Poison        0
# Fire         43
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     85
# Name: 088, dtype: int64
# Lightning    74
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     64
# Name: 088, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 088, dtype: int64
# Lightning    0
# Poison       0
# Fire         4
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 091, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 091, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 091, dtype: int64
# Lightning    0
# Poison       0
# Fire         4
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 091, dtype: int64
# Lightning    0
# Poison       0
# Fire         4
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 091, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 091, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 091, dtype: int64
# Lightning     0
# Poison        0
# Fire         34
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     75
# Name: 108, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 108, dtype: int64
# Lightning      0
# Poison         0
# Fire           2
# Falling        0
# Radiant        0
# Necrotic       0
# Psychic        0
# Ice            0
# Acid           0
# Thunder        0
# Physical     175
# Name: 108, dtype: int64
# Lightning      0
# Poison         0
# Fire           9
# Falling        0
# Radiant        0
# Necrotic       0
# Psychic        0
# Ice            0
# Acid           0
# Thunder        0
# Physical     203
# Name: 108, dtype: int64
# Lightning     0
# Poison        0
# Fire         38
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     42
# Name: 108, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     43
# Name: 108, dtype: int64
# Lightning      0
# Poison         0
# Fire         168
# Falling        0
# Radiant        0
# Necrotic       0
# Psychic        0
# Ice            0
# Acid           0
# Thunder        0
# Physical      86
# Name: 108, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic     22
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 101, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 101, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic     11
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 101, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic     22
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 101, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic     22
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 101, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic     11
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 101, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic     22
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical      0
# Name: 101, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 024, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 024, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 024, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 024, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 024, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 024, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 024, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     24
# Name: 113, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     0
# Name: 113, dtype: int64
# Lightning    0
# Poison       0
# Fire         0
# Falling      0
# Radiant      0
# Necrotic     0
# Psychic      0
# Ice          0
# Acid         0
# Thunder      0
# Physical     6
# Name: 113, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     14
# Name: 113, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       0
# Ice           0
# Acid          0
# Thunder       0
# Physical     60
# Name: 113, dtype: int64
# Lightning     0
# Poison        0
# Fire          0
# Falling       0
# Radiant       0
# Necrotic      0
# Psychic       4
# Ice           0
# Acid          0
# Thunder       0
# Physical     27
# Name: 113, dtype: int64

# %%
for singleFile in damageTakens:
    accmData = []
    for chars in range(0,7):
        chararr, ii = process_file(rootDirectory, singleFile, chars)
        ll = plt.figure(dpi=99)#;, facecolor='w', edgecolor='k')
        #plt.figure(figsize=(20,10))
        #gplt = accmData[0].plot.area(stacked=True, figsize=(48,27), colormap="tab20c")
        accmData[chars]
        gplt = accmData[chars].rename(index={str(accmData[chars].index[-1]): chararr[chars]}).plot.barh(ax = plt.gca(), stacked=False, figsize=(32,18), colormap=CustomCmap)
        gplt.set_facecolor('#121212')
        #gplt.plot()
        plt.savefig("perepialt/" + chararr[chars] + ".bar.taken." + str(ii) +".png")
        plt.cla()
        plt.close(ll)
    print("Finished: " + singleFile)
